# %%
#Lesson 1
# Course details : 
#  https://github.com/CoreyMSchafer/code_snippets/blob/master/Python/Pandas/02-DataFrames/Snippets.ipynb
#  https://www.youtube.com/watch?v=zmdjNSmRXF4&list=PLSLQ7uyfNIItZf404-TviaeM01pnebr5K&index=2

import pandas as pd

# %%
df = pd.read_csv('my_csv/survey_results_public.csv')

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
#Check rows and columns , not a method , its an attribute so we don't use () 
df.shape
# Out:
# (19690, 114)

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 19685       19686  I am a developer by profession     55-64 years old
# 19686       19687           I am learning to code     45-54 years old
# 19687       19688     I code primarily as a hobby  Under 18 years old
# 19688       19689  I am a developer by profession     35-44 years old
# 19689       19690  I am a developer by profession     45-54 years old
#
#                                               Employment  \
# 0                                    Employed, full-time
# ...

# %%
# give more info on datatypes, no. of rows , columns + data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19690 entries, 0 to 19689
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 17.1+ MB

# %%
# change number of columns and rows to display when we execute a df 
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',87)

# %%
# 80 columns display
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 19685       19686  I am a developer by profession     55-64 years old
# 19686       19687           I am learning to code     45-54 years old
# 19687       19688     I code primarily as a hobby  Under 18 years old
# 19688       19689  I am a developer by profession     35-44 years old
# 19689       19690  I am a developer by profession     45-54 years old
#
#                                               Employment  \
# 0                                    Employed, full-time
# ...

# %%
schema_df = pd.read_csv('my_csv/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0    QID2  MainBranch  Which of the following options best describes ...
# 1  QID127         Age                                 What is your age?*
# 2  QID296  Employment  Which of the following best describes your cur...
# 3  QID308  RemoteWork  Which best describes your current work situation?
# 4  QID341       Check  Just checking to make sure you are paying atte...
#
#   force_resp type selector
# 0       True   MC     SAVR
# 1       True   MC     SAVR
# 2       True   MC     MAVR
# 3      False   MC     SAVR
# 4       True   MC     SAVR

# %%
schema_df.head(10)
# Out:
#       qid             qname  \
# 0    QID2        MainBranch
# 1  QID127               Age
# 2  QID296        Employment
# 3  QID308        RemoteWork
# 4  QID341             Check
# 5  QID297  CodingActivities
# 6   QID25           EdLevel
# 7  QID276         LearnCode
# 8  QID281   LearnCodeOnline
# 9  QID331           TechDoc
#
#                                             question force_resp type selector
# 0  Which of the following options best describes ...       True   MC     SAVR
# 1                                 What is your age?*       True   MC     SAVR
# 2  Which of the following best describes your cur...       True   MC     MAVR
# 3  Which best describes your current work situation?      False   MC     SAVR
# 4  Just checking to make sure you are paying atte...       True   MC     SAVR
# 5  Which of the following best describes the code...      False   MC     MAVR
# 6  Which of the following best describes the high...       True   MC     SAVR
# ...

# %%
schema_df.tail()
# Out:
#        qid            qname  \
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 82  Learning and using new technology, including p...        NaN   MC     MAVR
# 83  Designing and building environments, databases...        NaN   MC     MAVR
# 84  Being a power user of a tool, developer langua...        NaN   MC     MAVR
# 85       Working with new and/or top-quality hardware        NaN   MC     MAVR
# 86  A well-staffed/sourced internal network that m...        NaN   MC     MAVR

# %%
schema_df.tail(10)
# Out:
#        qid            qname  \
# 77  QID290      Frequency_3
# 78  QID337   JobSatPoints_1
# 79  QID337   JobSatPoints_4
# 80  QID337   JobSatPoints_5
# 81  QID337   JobSatPoints_6
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 77  Encountering knowledge silos (where one indivi...        NaN   MC     MAVR
# 78                       Driving strategy for my team        NaN   MC     MAVR
# 79                        Contributing to open source        NaN   MC     MAVR
# 80                     Securing data and environments        NaN   MC     MAVR
# 81  Improving quality of code and developer enviro...        NaN   MC     MAVR
# 82  Learning and using new technology, including p...        NaN   MC     MAVR
# 83  Designing and building environments, databases...        NaN   MC     MAVR
# ...

# %%
# Lesson 2 : Dataframe

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df[['first','email']]
# Out:
#    first                    email
# 0  Corey  CoreyMSchafer@gmail.com
# 1   Jane        JaneDoe@email.com
# 2   John        JohnDoe@email.com

# %%
df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
df.iloc[[0,1],[1,2]]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com

# %%
df.loc[[0,2],['last','email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 2      Doe        JohnDoe@email.com

# %%
df.loc[0:1,'first':'last']
# Out:
#    first     last
# 0  Corey  Schafer
# 1   Jane      Doe

# %%
df.iloc[[0,1],2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')
